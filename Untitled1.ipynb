# %% [markdown]
# <a href="https://colab.research.google.com/github/saysaw9/Assignment-1-DS-101/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_plants = pd.DataFrame(pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Data_agro.xlsx'))
df_flight_dates = (pd.read_excel('/content/drive/MyDrive/Colab Notebooks/Data_agro.xlsx', sheet_name=[1]))

# %%
df_plants = df_plants.dropna(subset=['Head Weight (g)','Radial Diameter (mm)','Polar Diameter (mm)','Diameter Ratio','Density (kg/L)'], thresh=1)

# %%
df_plants[['Head Weight (g)','Radial Diameter (mm)','Polar Diameter (mm)','Diameter Ratio','Density (kg/L)']].isnull().sum()
# Out:
# Head Weight (g)          0
# Radial Diameter (mm)     0
# Polar Diameter (mm)      0
# Diameter Ratio           2
# Density (kg/L)          82
# dtype: int64

# %%
df_plants
# Out:
#       Batch Number Plant Date  Class  ...  Check Date  Flight Date  Remove
# 75             402 2020-04-11      2  ...  2020-05-22          NaT     NaN
# 76             402 2020-04-11      4  ...  2020-05-22          NaT       r
# 77             402 2020-04-11      5  ...  2020-05-22          NaT     NaN
# 78             402 2020-04-11      5  ...  2020-05-22          NaT     NaN
# 79             402 2020-04-11      3  ...  2020-05-22          NaT     NaN
# ...            ...        ...    ...  ...         ...          ...     ...
# 4854           738 2020-08-27      4  ...  2020-10-20          NaT     NaN
# 4855           738 2020-08-27      5  ...  2020-10-20          NaT     NaN
# 4856           738 2020-08-27      3  ...  2020-10-20          NaT     NaN
# 4857           738 2020-08-27      4  ...  2020-10-20          NaT     NaN
# 4858           738 2020-08-27      2  ...  2020-10-20          NaT     NaN
#
# [4754 rows x 15 columns]

# %%
df_plants=df_plants.drop(columns=['Leaves'])

# %%
df_plants
# Out:
#       Batch Number Plant Date  Class  ...  Check Date  Flight Date  Remove
# 75             402 2020-04-11      2  ...  2020-05-22          NaT     NaN
# 76             402 2020-04-11      4  ...  2020-05-22          NaT       r
# 77             402 2020-04-11      5  ...  2020-05-22          NaT     NaN
# 78             402 2020-04-11      5  ...  2020-05-22          NaT     NaN
# 79             402 2020-04-11      3  ...  2020-05-22          NaT     NaN
# ...            ...        ...    ...  ...         ...          ...     ...
# 4854           738 2020-08-27      4  ...  2020-10-20          NaT     NaN
# 4855           738 2020-08-27      5  ...  2020-10-20          NaT     NaN
# 4856           738 2020-08-27      3  ...  2020-10-20          NaT     NaN
# 4857           738 2020-08-27      4  ...  2020-10-20          NaT     NaN
# 4858           738 2020-08-27      2  ...  2020-10-20          NaT     NaN
#
# [4754 rows x 14 columns]

# %%
df_plants.isnull().sum()
# Out:
# Batch Number               0
# Plant Date               174
# Class                      0
# Fresh Weight (g)           0
# Head Weight (g)            0
# Radial Diameter (mm)       0
# Polar Diameter (mm)        0
# Diameter Ratio             2
# Density (kg/L)            82
# Leaf Area (cm^2)           1
# Square ID                  0
# Check Date                 0
# Flight Date             4282
# Remove                  4684
# dtype: int64

# %%
df_plants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4754 entries, 75 to 4858
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Batch Number          4754 non-null   int64
#  1   Plant Date            4580 non-null   datetime64[ns]
#  2   Class                 4754 non-null   int64
#  3   Fresh Weight (g)      4754 non-null   float64
#  4   Head Weight (g)       4754 non-null   float64
#  5   Radial Diameter (mm)  4754 non-null   float64
#  6   Polar Diameter (mm)   4754 non-null   float64
#  7   Diameter Ratio        4752 non-null   float64
#  8   Density (kg/L)        4672 non-null   float64
#  9   Leaf Area (cm^2)      4753 non-null   float64
#  10  Square ID             4754 non-null   int64
#  11  Check Date            4754 non-null   datetime64[ns]
#  12  Flight Date           472 non-null    datetime64[ns]
#  13  Remove                70 non-null     object
# ...

# %%
df_plants.drop(df_plants.index[df_plants['Remove'] == 'r'], inplace = True)

# %%
df_plants
# Out:
#       Batch Number Plant Date  Class  ...  Check Date  Flight Date  Remove
# 75             402 2020-04-11      2  ...  2020-05-22          NaT     NaN
# 77             402 2020-04-11      5  ...  2020-05-22          NaT     NaN
# 78             402 2020-04-11      5  ...  2020-05-22          NaT     NaN
# 79             402 2020-04-11      3  ...  2020-05-22          NaT     NaN
# 80             402 2020-04-11      1  ...  2020-05-22          NaT     NaN
# ...            ...        ...    ...  ...         ...          ...     ...
# 4854           738 2020-08-27      4  ...  2020-10-20          NaT     NaN
# 4855           738 2020-08-27      5  ...  2020-10-20          NaT     NaN
# 4856           738 2020-08-27      3  ...  2020-10-20          NaT     NaN
# 4857           738 2020-08-27      4  ...  2020-10-20          NaT     NaN
# 4858           738 2020-08-27      2  ...  2020-10-20          NaT     NaN
#
# [4684 rows x 14 columns]

# %%
df_plants.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 4684 entries, 75 to 4858
# Data columns (total 14 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Batch Number          4684 non-null   int64
#  1   Plant Date            4510 non-null   datetime64[ns]
#  2   Class                 4684 non-null   int64
#  3   Fresh Weight (g)      4684 non-null   float64
#  4   Head Weight (g)       4684 non-null   float64
#  5   Radial Diameter (mm)  4684 non-null   float64
#  6   Polar Diameter (mm)   4684 non-null   float64
#  7   Diameter Ratio        4682 non-null   float64
#  8   Density (kg/L)        4602 non-null   float64
#  9   Leaf Area (cm^2)      4683 non-null   float64
#  10  Square ID             4684 non-null   int64
#  11  Check Date            4684 non-null   datetime64[ns]
#  12  Flight Date           468 non-null    datetime64[ns]
#  13  Remove                0 non-null      object
# ...

# %%
df_plants['Density (kg/L)'].dropna()
# Out:
# 75      0.149230
# 77      0.298416
# 78      0.198625
# 79      0.208891
# 80      0.122498
#           ...
# 4774    0.105631
# 4775    0.139568
# 4776    0.147574
# 4777    0.160779
# 4778    0.162254
# Name: Density (kg/L), Length: 4602, dtype: float64

# %%
df_flight_dates
# Out:
# {1:     Batch Number Flight Date
#  0            402  2020-04-30
#  1            408  2020-04-30
#  2            409  2020-04-30
#  3            466  2020-07-01
#  4            467  2020-07-01
#  5            468  2020-07-01
#  6            469  2020-07-06
#  7            471  2020-07-02
#  8            472  2020-07-02
#  9            473  2020-07-02
#  10           474  2020-07-03
#  11           475  2020-07-03
#  12           477  2020-07-03
#  13           478  2020-07-02
#  14           510  2020-07-08
#  15           511  2020-07-15
#  16           514  2020-07-09
#  17           517  2020-07-08
#  18           521  2020-07-08
#  19           534  2020-07-17
#  20           538  2020-07-13
#  21           541  2020-07-13
#  22           542  2020-07-13
#  23           582  2020-07-28
#  24           586  2020-07-28
#  25           587  2020-07-28
#  26           589  2020-07-31
#  27           590  2020-07-31
#  28           596  2020-07-31
#  29           597  2020-07-31
# ...

# %%
from numpy import NAN
def compute_flight_dates():
  if df_plants['Batch Number'] == df_flight_dates['Plant Date'] & df_plants['Flight Date'] == NAN:
    df_plants['Flight Date'] = df_flight_dates['Flight Date']
  else:
    pass
